# %% [markdown]
# ![This is an image](https://letsgrowmore.in/wp-content/uploads/2021/05/growmore-removebg-preview.png)
# ## ***Virtual Internship Program***
# ***Data Science  Tasks***
# ### ***All Credit to***
# ### ***Author: SARAVANAVEL***

# %% [markdown]
# # ***BEGINNER LEVEL TASK***
# ### Task 3 -Music recommender system
#
# Music recommender system can suggest songs to users based on their listening pattern.
#
# Datasetlinks  https://www.kaggle.com/c/kkbox-music-recommendation-challenge/data

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import time
import Recommenders as Recommenders

# %% [markdown]
# ## Load member data

# %% [markdown]
# <B><I>Correcting date format</B></I>

# %%
members = pd.read_csv(r'members.csv',parse_dates=["registration_init_time","expiration_date"])
members.head()
# Out:
#                                            msno  city  bd gender  \
# 0  XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=     1   0    NaN
# 1  UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=     1   0    NaN
# 2  D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=     1   0    NaN
# 3  mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=     1   0    NaN
# 4  q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=     1   0    NaN
#
#    registered_via registration_init_time expiration_date
# 0               7             2011-08-20      2017-09-20
# 1               7             2015-06-28      2017-06-22
# 2               4             2016-04-11      2017-07-12
# 3               9             2015-09-06      2015-09-07
# 4               4             2017-01-26      2017-06-13

# %% [markdown]
# ## Load train data

# %%
df_train = pd.read_csv(r'train.csv')
df_train.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target
# 0              Explore  online-playlist       1
# 1  Local playlist more   local-playlist       1
# 2  Local playlist more   local-playlist       1
# 3  Local playlist more   local-playlist       1
# 4              Explore  online-playlist       1

# %% [markdown]
# ## Load songs data

# %%
df_songs = pd.read_csv(r'songs.csv')
df_songs.head()
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328       444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781       465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554       465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329       726
#
#         artist_name                            composer     lyricist  language
# 0  張信哲 (Jeff Chang)                                  董貞          何啟弘       3.0
# 1         BLACKPINK  TEDDY|  FUTURE BOUNCE|  Bekuh BOOM        TEDDY      31.0
# 2      SUPER JUNIOR                                 NaN          NaN      31.0
# 3             S.H.E                                 湯小康          徐世珍       3.0
# 4              貴族精選                         Traditional  Traditional      52.0

# %% [markdown]
# ## Load song_extra data

# %%
df_songs_extra = pd.read_csv(r'song_extra_info.csv')
df_songs_extra.head()
# Out:
#                                         song_id             name          isrc
# 0  LP7pLJoJFBvyuUwvu+oLzjT+bI+UeBPURCecJsX1jjs=               我們  TWUM71200043
# 1  ClazTFnk6r0Bnuie44bocdNMM3rdlrq0bCGAsGUWcHE=  Let Me Love You  QMZSY1600015
# 2  u2ja/bZE3zhCGxvbbOB3zOoUjx27u40cf5g09UXMoKQ=              原諒我  TWA530887303
# 3  92Fqsy0+p6+RHe2EoLKjHahORHR1Kq1TBJoClW9v+Ts=          Classic  USSM11301446
# 4  0QFmz/+rJy1Q56C1DuYqT9hKKqi5TUqx0sN0IwvoHrw=             愛投羅網  TWA471306001

# %% [markdown]
# ## Load test data

# %%
df_test = pd.read_csv(r'test.csv')
df_test.head()
# Out:
#    id                                          msno  \
# 0   0  V8ruy7SGk7tDm3zA51DPpn6qutt+vmKMBKa21dp54uM=
# 1   1  V8ruy7SGk7tDm3zA51DPpn6qutt+vmKMBKa21dp54uM=
# 2   2  /uQAlrAkaczV+nWCd2sPF2ekvXPRipV7q0l+gbLuxjw=
# 3   3  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=
# 4   4  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=
#
#                                         song_id source_system_tab  \
# 0  WmHKgKMlp1lQMecNdNvDMkvIycZYHnFwDT72I5sIssc=        my library
# 1  y/rsZ9DC7FwK5F2PK2D5mj+aOBUJAjuu3dZ14NgE0vM=        my library
# 2  8eZLFOdGVdXBSqoAv5nsLigeH2BvKXzTQYtUM53I0k4=          discover
# 3  ztCf8thYsS4YN3GcIL/bvoxLm/T5mYBVKOO4C9NiVfQ=             radio
# 4  MKVMpslKcQhMaFEgcEQhEfi5+RZhMYlU3eRDpySrH8Y=             radio
#
#     source_screen_name          source_type
# 0  Local playlist more        local-library
# 1  Local playlist more        local-library
# 2                  NaN  song-based-playlist
# 3                Radio                radio
# 4                Radio                radio

# %% [markdown]
# ## Creating a new data

# %%
res = df_train.merge(df_songs[['song_id','song_length','genre_ids','artist_name','language']], on=['song_id'], how='left')
res.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target  song_length genre_ids  \
# 0              Explore  online-playlist       1     206471.0       359
# 1  Local playlist more   local-playlist       1     284584.0      1259
# 2  Local playlist more   local-playlist       1     225396.0      1259
# 3  Local playlist more   local-playlist       1     255512.0      1019
# 4              Explore  online-playlist       1     187802.0      1011
#
#        artist_name  language
# 0         Bastille      52.0
# 1  Various Artists      52.0
# 2              Nas      52.0
# 3         Soundway      -1.0
# 4      Brett Young      52.0

# %%
res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7377418 entries, 0 to 7377417
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   msno                object
#  1   song_id             object
#  2   source_system_tab   object
#  3   source_screen_name  object
#  4   source_type         object
#  5   target              int64
#  6   song_length         float64
#  7   genre_ids           object
#  8   artist_name         object
#  9   language            float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 619.1+ MB

# %%
train = res.merge(df_songs_extra,on=['song_id'],how = 'left')
train.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target  song_length genre_ids  \
# 0              Explore  online-playlist       1     206471.0       359
# 1  Local playlist more   local-playlist       1     284584.0      1259
# 2  Local playlist more   local-playlist       1     225396.0      1259
# 3  Local playlist more   local-playlist       1     255512.0      1019
# 4              Explore  online-playlist       1     187802.0      1011
#
#        artist_name  language                                     name  \
# 0         Bastille      52.0                               Good Grief
# 1  Various Artists      52.0                       Lords of Cardboard
# 2              Nas      52.0  Hip Hop Is Dead(Album Version (Edited))
# 3         Soundway      -1.0                             Disco Africa
# 4      Brett Young      52.0                        Sleep Without You
#
#            isrc
# 0  GBUM71602854
# 1  US3C69910183
# 2  USUM70618761
# 3  GBUQH1000063
# 4  QM3E21606003

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7377418 entries, 0 to 7377417
# Data columns (total 12 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   msno                object
#  1   song_id             object
#  2   source_system_tab   object
#  3   source_screen_name  object
#  4   source_type         object
#  5   target              int64
#  6   song_length         float64
#  7   genre_ids           object
#  8   artist_name         object
#  9   language            float64
#  10  name                object
#  11  isrc                object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 731.7+ MB

# %%
song_id = train.loc[:,["name","target"]]
song1 = song_id.groupby(["name"],as_index=False).count().rename(columns = {"target":"listen_count"})

# %%
song1.head()
# Out:
#                                                 name  listen_count
# 0     24karats –type S-(與放浪兄弟EXILE、DOBELMAN合作超跳嘻哈單曲)             5
# 1   A Gentle Dissolve (Shawn Lee Ping Pong Orches...             1
# 2                                              A-CHA             2
# 3                                            Adicto              1
# 4                         Be Your Sound (Radio Edit)            10

# %%
dataset=train.merge(song1,on=['name'],how= 'left')

# %%
df=pd.DataFrame(dataset)

# %%
df.drop(columns=['source_system_tab','source_screen_name','source_type','target','isrc'],axis=1,inplace=True)
df=df.rename(columns={'msno':'user_id'})

# %% [markdown]
# ## Loading our new dataset

# %%
df.head()
# Out:
#                                         user_id  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id  song_length genre_ids  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=     206471.0       359
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=     284584.0      1259
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=     225396.0      1259
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=     255512.0      1019
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=     187802.0      1011
#
#        artist_name  language                                     name  \
# 0         Bastille      52.0                               Good Grief
# 1  Various Artists      52.0                       Lords of Cardboard
# 2              Nas      52.0  Hip Hop Is Dead(Album Version (Edited))
# 3         Soundway      -1.0                             Disco Africa
# 4      Brett Young      52.0                        Sleep Without You
#
#    listen_count
# 0         293.0
# 1           1.0
# 2           4.0
# 3           1.0
# 4         412.0

# %% [markdown]
# ## Data Preprocessing

# %%
df.shape
# Out:
# (7377418, 8)

# %%
#checking null values
df.isnull().sum()
# Out:
# user_id              0
# song_id              0
# song_length        114
# genre_ids       118455
# artist_name        114
# language           150
# name              1457
# listen_count      1457
# dtype: int64

# %%
#filling null values
df['song_length'].fillna('0',inplace=True)
df['genre_ids'].fillna('0',inplace=True)
df['artist_name'].fillna('none',inplace=True)
df['language'].fillna('0',inplace=True)
df['name'].fillna('none',inplace=True)
df['listen_count'].fillna('0',inplace=True)

# %%
#Rechecking null values
df.isnull().sum()
# Out:
# user_id         0
# song_id         0
# song_length     0
# genre_ids       0
# artist_name     0
# language        0
# name            0
# listen_count    0
# dtype: int64

# %%
print("Total no of songs:",len(df))
# Out:
# Total no of songs: 7377418

# %% [markdown]
# ## Create a subset of the dataset

# %%
df = df.head(10000)

#Merge song title and artist_name columns to make a new column
df['song'] = df['name'].map(str) + " - " + df['artist_name']

# %% [markdown]
# ## Showing the most popular songs in the dataset

# %% [markdown]
# The column listen_count denotes the no of times the song has been listened.Using this column, we’ll find the dataframe consisting of popular songs:

# %%
song_gr = df.groupby(['song']).agg({'listen_count': 'count'}).reset_index()
grouped_sum = song_gr['listen_count'].sum()
song_gr['percentage']  = song_gr['listen_count'].div(grouped_sum)*100
song_gr.sort_values(['listen_count', 'song'], ascending = [0,1])
# Out:
#                                                    song  listen_count  \
# 3166                              告白氣球 - 周杰倫 (Jay Chou)            62
# 3630                           帥到分手 - 周湯豪 (NICKTHEREAL)            54
# 5194       謝謝妳愛我 (Thanks For Your Love) - 謝和弦 (R-chord)            53
# 428                           Closer - The Chainsmokers            38
# 2866             你，好不好？ (How Have You Been?) - Eric 周興哲            38
# ...                                                 ...           ...
# 5581                           착한여자(GOOD TO YOU) - 2NE1             1
# 5583                                 촌스럽게 왜 이래 - K.Will             1
# 5584     칼로리 송 (통통한거라 믿고 싶겠지) Calorie Song - Coffee Boy             1
# 5585  헤어질걸 알기에(i know| we will breake up  ) - Dia Tr...             1
# 5586                                 Ｌｉａｒ - ONE OK ROCK             1
#
#       percentage
# 3166        0.62
# 3630        0.54
# 5194        0.53
# 428         0.38
# 2866        0.38
# ...          ...
# 5581        0.01
# 5583        0.01
# 5584        0.01
# 5585        0.01
# 5586        0.01
#
# [5587 rows x 3 columns]

# %% [markdown]
#  ## Count number of unique users in the dataset

# %%
users = df['user_id'].unique()
print("The no. of unique users:", len(users))
# Out:
# The no. of unique users: 1622

# %% [markdown]
# Now, we define a dataframe train which will create a song recommender

# %% [markdown]
#  ### Count the number of unique songs in the dataset

# %%
###Fill in the code here
songs = df['song'].unique()
len(songs)
# Out:
# 5587

# %% [markdown]
# # Create a song recommender

# %%
train_data, test_data = train_test_split(df, test_size = 0.20, random_state=0)
print(train.head(5))
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target  song_length genre_ids  \
# 0              Explore  online-playlist       1     206471.0       359
# 1  Local playlist more   local-playlist       1     284584.0      1259
# 2  Local playlist more   local-playlist       1     225396.0      1259
# 3  Local playlist more   local-playlist       1     255512.0      1019
# 4              Explore  online-playlist       1     187802.0      1011
#
#        artist_name  language                                     name  \
# 0         Bastille      52.0                               Good Grief
# 1  Various Artists      52.0                       Lords of Cardboard
# 2              Nas      52.0  Hip Hop Is Dead(Album Version (Edited))
# 3         Soundway      -1.0                             Disco Africa
# 4      Brett Young      52.0                        Sleep Without You
#
#            isrc
# 0  GBUM71602854
# 1  US3C69910183
# 2  USUM70618761
# 3  GBUQH1000063
# 4  QM3E21606003

# %% [markdown]
# ## Creating Popularity based Music Recommendation

# %% [markdown]
# Using  popularity_recommender class we made in Recommenders.py package, we create the list given below:

# %%
pm = Recommenders.popularity_recommender_py()                               #create an instance of the class
pm.create(train_data, 'user_id', 'song')

user_id1 = users[5]                                                          #Recommended songs list for a user
pm.recommend(user_id1)
# Out:
#                                            user_id  \
# 2659  uQQHTQJ1nVEkBfbXe0f1/J9ML5eQhsQiocCV5TvvCRI=
# 3055  uQQHTQJ1nVEkBfbXe0f1/J9ML5eQhsQiocCV5TvvCRI=
# 4394  uQQHTQJ1nVEkBfbXe0f1/J9ML5eQhsQiocCV5TvvCRI=
# 2400  uQQHTQJ1nVEkBfbXe0f1/J9ML5eQhsQiocCV5TvvCRI=
# 4678  uQQHTQJ1nVEkBfbXe0f1/J9ML5eQhsQiocCV5TvvCRI=
# 351   uQQHTQJ1nVEkBfbXe0f1/J9ML5eQhsQiocCV5TvvCRI=
# 2883  uQQHTQJ1nVEkBfbXe0f1/J9ML5eQhsQiocCV5TvvCRI=
# 3107  uQQHTQJ1nVEkBfbXe0f1/J9ML5eQhsQiocCV5TvvCRI=
# 2874  uQQHTQJ1nVEkBfbXe0f1/J9ML5eQhsQiocCV5TvvCRI=
# 464   uQQHTQJ1nVEkBfbXe0f1/J9ML5eQhsQiocCV5TvvCRI=
#
#                                                song  score  Rank
# 2659                          告白氣球 - 周杰倫 (Jay Chou)     53   1.0
# 3055                       帥到分手 - 周湯豪 (NICKTHEREAL)     47   2.0
# 4394   謝謝妳愛我 (Thanks For Your Love) - 謝和弦 (R-chord)     47   3.0
# 2400         你，好不好？ (How Have You Been?) - Eric 周興哲     34   4.0
# 4678                                 默 - aMEI (張惠妹)     29   5.0
# 351                       Closer - The Chainsmokers     28   6.0
# 2883      好愛好散 (Blue Love Theme) - 陳勢安 (Andrew Tan)     28   7.0
# 3107         後來的我們 (Here| After| Us) - 五月天 (Mayday)     27   8.0
# 2874  好好 (想把你寫成一首歌) (Song About You) - 五月天 (Mayday)     25   9.0
# 464            Don't Let Me Down - The Chainsmokers     23  10.0

# %%
user_id2 = users[45]
pm.recommend(user_id2)
# Out:
#                                            user_id  \
# 2659  6VAZ05qs9gRNM6FZgGvEs9SukGVvBwF/EJ3pMWxgC24=
# 3055  6VAZ05qs9gRNM6FZgGvEs9SukGVvBwF/EJ3pMWxgC24=
# 4394  6VAZ05qs9gRNM6FZgGvEs9SukGVvBwF/EJ3pMWxgC24=
# 2400  6VAZ05qs9gRNM6FZgGvEs9SukGVvBwF/EJ3pMWxgC24=
# 4678  6VAZ05qs9gRNM6FZgGvEs9SukGVvBwF/EJ3pMWxgC24=
# 351   6VAZ05qs9gRNM6FZgGvEs9SukGVvBwF/EJ3pMWxgC24=
# 2883  6VAZ05qs9gRNM6FZgGvEs9SukGVvBwF/EJ3pMWxgC24=
# 3107  6VAZ05qs9gRNM6FZgGvEs9SukGVvBwF/EJ3pMWxgC24=
# 2874  6VAZ05qs9gRNM6FZgGvEs9SukGVvBwF/EJ3pMWxgC24=
# 464   6VAZ05qs9gRNM6FZgGvEs9SukGVvBwF/EJ3pMWxgC24=
#
#                                                song  score  Rank
# 2659                          告白氣球 - 周杰倫 (Jay Chou)     53   1.0
# 3055                       帥到分手 - 周湯豪 (NICKTHEREAL)     47   2.0
# 4394   謝謝妳愛我 (Thanks For Your Love) - 謝和弦 (R-chord)     47   3.0
# 2400         你，好不好？ (How Have You Been?) - Eric 周興哲     34   4.0
# 4678                                 默 - aMEI (張惠妹)     29   5.0
# 351                       Closer - The Chainsmokers     28   6.0
# 2883      好愛好散 (Blue Love Theme) - 陳勢安 (Andrew Tan)     28   7.0
# 3107         後來的我們 (Here| After| Us) - 五月天 (Mayday)     27   8.0
# 2874  好好 (想把你寫成一首歌) (Song About You) - 五月天 (Mayday)     25   9.0
# 464            Don't Let Me Down - The Chainsmokers     23  10.0

# %% [markdown]
# ## Build a song recommender with personalization
#
# We now create an item similarity based collaborative filtering model that allows us to make personalized recommendations to each user.

# %% [markdown]
# ### Creating Similarity based Music Recommendation in Python:

# %%
is_model = Recommenders.item_similarity_recommender_py()
is_model.create(train_data, 'user_id', 'song')

# %% [markdown]
# ### Use the personalized model to make some song recommendations

# %%
#Print the songs for the user in training data
user_id1 = users[1]
#Fill in the code here
user_items2 = is_model.get_user_items(user_id2)
print("------------------------------------------------------------------------------------")
print("Songs played by second user %s:" % user_id2)
print("------------------------------------------------------------------------------------")

for user_item in user_items1:
    print(user_item)

print("----------------------------------------------------------------------")
print("Similar songs recommended for the second user:")
print("----------------------------------------------------------------------")

#Recommend songs for the user using personalized model
is_model.recommend(user_id1)
# Out:
# ------------------------------------------------------------------------------------
# Songs played by second user 6VAZ05qs9gRNM6FZgGvEs9SukGVvBwF/EJ3pMWxgC24=:
# ------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-7ca04e59403a> in <module>
#       7 print("------------------------------------------------------------------------------------")
#       8
# ----> 9 for user_item in user_items1:
#      10     print(user_item)
#      11
#
# NameError: name 'user_items1' is not defined

# %%
user_id2 = users[7]
#Fill in the code here
user_items2 = is_model.get_user_items(user_id2)
print("------------------------------------------------------------------------------------")
print("Songs played by second user %s:" % user_id2)
print("------------------------------------------------------------------------------------")

for user_item in user_items2:
    print(user_item)

print("----------------------------------------------------------------------")
print("Similar songs recommended for the second user:")
print("----------------------------------------------------------------------")

#Recommend songs for the user using personalized model
is_model.recommend(user_id2)
# Out:
# ------------------------------------------------------------------------------------
# Songs played by second user Vgeu+u3vXE0FhQtG/Vr3I/U3V0TX/jzQAEBhi3S3qi0=:
# ------------------------------------------------------------------------------------
# 親愛陌生人【土豆網偶像劇[歡迎愛光臨]片頭曲】 - 丁噹 (Della)
# 道聽塗說 (Remembering you) - 林芯儀 (Shennio Lin)
# 愛磁場 - 張韶涵 (Angela Chang)
# 宇宙小姐 - S.H.E
# 愛旅行的人 - 張韶涵 (Angela Chang)
# 敢愛敢當 - 丁噹 (Della)
# 九號球 - [逆轉勝] 五月天∕怪獸 原聲原創紀 ([Second Chance] Soundtrack & Autobiography of Mayday Monster)
# 刺情 - 張韶涵 (Angela Chang)
# Baby - Justin Bieber
# Never Forget You - 張韶涵 (Angela Chang)
# 安靜了 - S.H.E
# ----------------------------------------------------------------------
# Similar songs recommended for the second user:
# ----------------------------------------------------------------------
# No. of unique songs for the user: 11
# no. of unique songs in the training set: 4722
# Non zero values in cooccurence_matrix :238
#                                         user_id  \
# 0  Vgeu+u3vXE0FhQtG/Vr3I/U3V0TX/jzQAEBhi3S3qi0=
# 1  Vgeu+u3vXE0FhQtG/Vr3I/U3V0TX/jzQAEBhi3S3qi0=
# 2  Vgeu+u3vXE0FhQtG/Vr3I/U3V0TX/jzQAEBhi3S3qi0=
# 3  Vgeu+u3vXE0FhQtG/Vr3I/U3V0TX/jzQAEBhi3S3qi0=
# 4  Vgeu+u3vXE0FhQtG/Vr3I/U3V0TX/jzQAEBhi3S3qi0=
# 5  Vgeu+u3vXE0FhQtG/Vr3I/U3V0TX/jzQAEBhi3S3qi0=
# 6  Vgeu+u3vXE0FhQtG/Vr3I/U3V0TX/jzQAEBhi3S3qi0=
# 7  Vgeu+u3vXE0FhQtG/Vr3I/U3V0TX/jzQAEBhi3S3qi0=
# 8  Vgeu+u3vXE0FhQtG/Vr3I/U3V0TX/jzQAEBhi3S3qi0=
# 9  Vgeu+u3vXE0FhQtG/Vr3I/U3V0TX/jzQAEBhi3S3qi0=
#
#                                     song     score rank
# 0                    I Wanna Be - Katy B  0.045455    1
# 1                     等著你回來 - 田馥甄 (Hebe)  0.045455    2
# 2  玩愛之徒 (Love Player) - 蔡依林 (Jolin Tsai)  0.045455    3
# 3                 我還在原地哭 - 朱俐靜 (Miu Chu)  0.045455    4
# 4                          SHERO - S.H.E  0.045455    5
# 5        遠路《晟俊與惠珍真愛之歌》 - Various Artists  0.045455    6
# 6                   The Spark - Afrojack  0.045455    7
# 7                           無路可退 - A-Lin  0.041667    8
# 8                            920 - A-Lin  0.032828    9
# 9   One Less Lonely Girl - Justin Bieber  0.032828   10

# %% [markdown]
# The lists of both the users in popularity based recommendation is the same but different in case of similarity-based recommendation.

# %% [markdown]
# ### We can also apply the model to find similar songs to any song in the dataset

# %%
is_model.get_similar_items(['One Less Lonely Girl - Justin Bieber'])
# Out:
# no. of unique songs in the training set: 4722
# Non zero values in cooccurence_matrix :21
#   user_id                              song     score rank
# 0               Bitch I'm Madonna - Madonna  0.500000    1
# 1          I Need Your Love - Calvin Harris  0.500000    2
# 2                              無路可退 - A-Lin  0.500000    3
# 3                            Work - Rihanna  0.500000    4
# 4                               920 - A-Lin  0.333333    5
# 5                      The Monster - Eminem  0.333333    6
# 6            Love Me Harder - Ariana Grande  0.333333    7
# 7               愛你愛到變成一首歌 - 陳零九 (Nine Chen)  0.250000    8
# 8                      Baby - Justin Bieber  0.250000    9
# 9                 分開的學問 - 邱鋒澤 (Qiu Feng Ze)  0.250000   10
